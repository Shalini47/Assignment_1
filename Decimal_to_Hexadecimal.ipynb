# %%
# function to convert  
# decimal to hexadecimal
import numpy as np 
def decToHexa():
    
      
    # char array to store  
    # hexadecimal number 
    random_number = np.random.randint(low=10, high=4000, size=1000)
    hexaDeciNum = [''] * 1000; 
    #Print random values
    print("Decimal number\n")
    for j in range(0,1000):
    	print(random_number[j])
    # counter for hexadecimal  
    # number array
    print("\nhexadecimal number\n") 
    for i in range(0,1000):
    	while(random_number[i] != 0): 
          
        # temporary variable  
        # to store remainder 
        	temp = 0; 
          
        # storing remainder  
        # in temp variable. 
        	temp = random_number[i]  % 16; 
          
        # check if temp < 10 
        	if(temp < 10): 
        		hexaDeciNum[i] = hexaDeciNum[i]+chr(temp + 48); 
            
        	else: 
        		hexaDeciNum[i] = hexaDeciNum[i]+chr(temp + 55); 
            
        	random_number[i] = int(random_number[i] / 16);
          
    # printing hexadecimal number 
    # array in reverse order
    	hexaDeciNum[i] = "".join(reversed(hexaDeciNum[i]))
    	print(hexaDeciNum[i])

 
# Driver Code 
decToHexa();
# Out:
# Decimal number
#
# 3434
# 3383
# 44
# 1257
# 979
# 1282
# 2318
# 1458
# 142
# 3859
# 3747
# 1760
# 411
# 19
# 965
# 3020
# 528
# 3436
# 1908
# 2135
# 1568
# 2305
# 3612
# 469
# 3846
# 3924
# 1543
# 832
# 2178
# 1328
# 2739
# 2767
# 1605
# 2599
# 2091
# 50
# 1519
# 1762
# 2039
# 3254
# 1077
# 537
# 2414
# 3825
# 289
# 489
# 2546
# 353
# 663
# 3851
# 283
# 3120
# 3191
# 1130
# 1930
# 2639
# 1794
# 3372
# 436
# 1587
# 2129
# 485
# 2785
# 1982
# 1576
# 520
# 3900
# 1653
# 891
# 3822
# 2194
# 3042
# 1217
# 3193
# 2964
# 780
# 359
# 3329
# 1237
# 1875
# 2239
# 1793
# 1010
# 2199
# 3834
# 200
# 2051
# 1274
# 2023
# 3055
# 3061
# 694
# 1917
# 2123
# 270
# 3699
# 915
# 2063
# 3795
# 698
# 2978
# 939
# 3120
# 3514
# 21
# 2363
# 218
# 1260
# 2830
# 396
# 3847
# 929
# 780
# 353
# 1540
# 1932
# 3843
# 2600
# 2362
# 1994
# 1981
# 1435
# 1293
# 1236
# 3655
# 796
# 928
# 2024
# 2274
# 560
# 2918
# 364
# 2093
# 2737
# 2336
# 721
# 896
# 673
# 2182
# 426
# 2465
# 842
# 3556
# 1867
# 3815
# 1918
# 147
# ...
